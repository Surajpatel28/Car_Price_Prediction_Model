# %% [markdown]
# #Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn import metrics

# %% [markdown]
# #Loading the data

# %%
car_dataset = pd.read_csv('car data.csv')

# %% [markdown]
# # Checking the dataset

# %%
car_dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car_dataset.shape
# Out:
# (301, 9)

# %%
car_dataset.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# checking the distribution of categorical data
print(car_dataset.Fuel_Type.value_counts())
print(car_dataset.Seller_Type.value_counts())
print(car_dataset.Transmission.value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %% [markdown]
# # Encoding the textual data into numerical values

# %%
# encoding Fuel_Type
car_dataset.replace({'Fuel_Type': {
    'Petrol': 0,
    'Diesel': 1,
    'CNG':2
}}, inplace=True)

# encoding Seller_Type
car_dataset.replace({'Seller_Type':{
    'Dealer':0,
    'Individual':1
}}, inplace=True)

# encoding Transmission
car_dataset.replace({'Transmission': {
    'Manual': 0,
    'Automatic': 1
}}, inplace=True)
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_16792\1796016511.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'Fuel_Type': {
# C:\Users\suraj\AppData\Local\Temp\ipykernel_16792\1796016511.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'Seller_Type':{
# C:\Users\suraj\AppData\Local\Temp\ipykernel_16792\1796016511.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_dataset.replace({'Transmission': {

# %%
car_dataset.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0

# %% [markdown]
# # Splitting the features and target values

# %%
X = car_dataset.drop(['Car_Name', 'Selling_Price'], axis=1)
Y = car_dataset['Selling_Price']

# %%
X
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          0            0             0
# 1    2013           9.54       43000          1            0             0
# 2    2017           9.85        6900          0            0             0
# 3    2011           4.15        5200          0            0             0
# 4    2014           6.87       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             0
# 297  2015           5.90       60000          0            0             0
# 298  2009          11.00       87934          0            0             0
# 299  2017          12.50        9000          1            0             0
# 300  2016           5.90        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [301 rows x 7 columns]

# %% [markdown]
# # Splitting the test and train data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=2)

# %% [markdown]
# # Loading the LinearRegression() model

# %%
model_linear = LinearRegression()

# %%
# Model fitting
model_linear.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
training_data_prediction = model_linear.predict(X_train)

# %%
# Calculating the r2_score
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error: ",(error_score))
# Out:
# R squared error:  0.8799451660493708

# %%
#plotting the data to visualize better
plt.scatter(Y_train, training_data_prediction, color='red', alpha=0.6)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.grid(True)
plt.show()

# %%
# Predicting on the test data
test_data_prediction = model_linear.predict(X_test)

# %%
# calculating the r2_score on test data
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared error: ",(error_score))
# Out:
# R squared error:  0.8365766715026374

# %%
# plotting the test data
plt.scatter(Y_test, test_data_prediction, color='red', alpha=0.6)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.grid(True)
plt.show()

# %%
friends_car = np.array([
    [2012, 6.98, 130000,	1,	1,	0, 1],
    [2014, 6.98, 150000,	1,	1,	0, 1],
    [2015, 6.18, 120000,	1,	1,	0, 1]])

friends_car_df = pd.DataFrame(friends_car, columns=X.columns)
prediction = model_linear.predict(friends_car_df)
# print(prediction)
print("The predictions are as follows: ")
for j,i in enumerate(prediction):
  print(f'The selling price for the {j+1} car is {i:.3} Lakh')
# Out:
# The predictions are as follows:
# The selling price for the 1 car is 2.82 Lakh
# The selling price for the 2 car is 3.51 Lakh
# The selling price for the 3 car is 3.77 Lakh

# %% [markdown]
# # Loading the Model

# %%
xgb_model = XGBRegressor(objective="reg:squarederror",random_state=42)

# %%
xgb_model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# testing on test data

# %%
test_data_predictions = xgb_model.predict(X_test)

# %%
# calculating the r2_score on test data
error_score = metrics.r2_score(Y_test, test_data_predictions)
print("R squared error: ",(error_score))
# Out:
# R squared error:  0.9807321370840111

# %%
# plotting the test data
plt.scatter(Y_test, test_data_predictions, color='red', alpha=0.6)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Prices vs Predicted Prices')
plt.grid(True)
plt.show()

# %% [markdown]
# - As we can see the xgboost model performs really good as compared to the linear regression model.

# %%
friends_car = np.array([
    [2012, 6.98, 130000,	1,	1,	0, 1],
    [2014, 6.98, 150000,	1,	1,	0, 1],
    [2015, 6.18, 120000,	1,	1,	0, 1]])

friends_car_df = pd.DataFrame(friends_car, columns=X.columns)
prediction = xgb_model.predict(friends_car_df)
# print(prediction)
print("The predictions are as follows: ")
for j,i in enumerate(prediction):
  print(f'The selling price for the {j+1} car is {i:.3} Lakh')
# Out:
# The predictions are as follows:
# The selling price for the 1 car is 4.33 Lakh
# The selling price for the 2 car is 4.4 Lakh
# The selling price for the 3 car is 4.64 Lakh
